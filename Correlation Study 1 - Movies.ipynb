# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Read data
df = pd.read_csv(r'C:\Mark\movies.csv')

# %%
# Initial look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# See if missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Drop rows with missing data
df = df.dropna()

# %%
# Extract the year
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Drop old year column
df = df.drop('year', axis=1)

# %%
# Rename new year column
df.rename(columns = {'yearcorrect':'year'}, inplace = True)

# %%
# View column data types
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# year          int32
# dtype: object

# %%
# Change budget and gross columns to type integer
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# View by gross in descending order
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  \
# 5445                                      Avatar      PG-13  Action
# 7445                           Avengers: Endgame      PG-13  Action
# 3045                                     Titanic      PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action
# 7244                      Avengers: Infinity War      PG-13  Action
# ...                                          ...        ...     ...
# 5640                                 Tanner Hall          R   Drama
# 2434                  Philadelphia Experiment II      PG-13  Action
# 3681                                Ginger Snaps  Not Rated   Drama
# 272                                     Parasite          R  Horror
# 3203                                  Trojan War      PG-13  Comedy
#
#                                released  score      votes  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0
# ...

# %%
# Drop any duplicates
df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
# Look for outliers in gross with box plot
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
# Check field correlation
df.corr()
# Out:
#             score     votes    budget     gross   runtime      year
# score    1.000000  0.474256  0.072001  0.222556  0.414068  0.061923
# votes    0.474256  1.000000  0.439675  0.614751  0.352303  0.203098
# budget   0.072001  0.439675  1.000000  0.740247  0.318695  0.320312
# gross    0.222556  0.614751  0.740247  1.000000  0.275796  0.268721
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000  0.075294
# year     0.061923  0.203098  0.320312  0.268721  0.075294  1.000000

# %%
# Visualize correlation values in maxtrix with heatmap
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix")
plt.xlabel("Movie feilds")
plt.ylabel("Movie feilds")
plt.show()

# %%
# View regression plot of gross and budget
slope, intercept, r_value, p_value, std_err = stats.linregress(df['budget'], df['gross'])
sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})

# Add R-squared value and p-value to the plot
plt.text(0,2800000000,f'R-squared: {round(r_value**2,4)}')
plt.text(0,2600000000,f'p-value: {p_value}')

# Add formula for predicting y values (yhat)
plt.text(0,2400000000,f'yhat: {round(slope,2)}x + {round(intercept,2)}')

# Add axis labels and a plot title
plt.xlabel('Budget (Hundred Millions USD)')
plt.ylabel('Gross Earnings (Billions USD)')
plt.title('Regression Analysis - Budget and Gross Earnings')

# Show the plot
plt.show()

# %%
# View regression plot of gross and score
slope, intercept, r_value, p_value, std_err = stats.linregress(df['score'], df['gross'])
sns.regplot(x="score", y="gross", data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})

# Add R-squared value and p-value to the plot
plt.text(2,2800000000,f'R-squared: {round(r_value**2,4)}')
plt.text(2,2600000000,f'p-value: {p_value}')

# Add formula for predicting y values (yhat)
plt.text(2,2400000000,f'yhat: {round(slope,2)}x + {round(intercept,2)}')

# Add axis labels and a plot title
plt.xlabel('Score Rating')
plt.ylabel('Gross Earnings (Billions USD)')
plt.title('Regression Analysis - Score and Gross Earnings')

# Show the plot
plt.show()

# %%
# Convert categorical variables to numeric
# category codes for use in correlation
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.corr()
# Out:
#               name    rating     genre  released     score     votes  \
# name      1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating   -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre     0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score     0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes     0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director  0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer    0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star     -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country  -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget    0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross     0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# company   0.021697 -0.092357 -0.071334 -0.002407  0.020656  0.118470
# ...

# %%
# Visualize extended correlation values in maxtrix with heatmap
correlation_matrix = df_numerized.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix Extended")
plt.xlabel("Movie fields")
plt.ylabel("Movie fields")
plt.show()
